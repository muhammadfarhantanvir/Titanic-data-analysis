# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Read the csv file into a DataFrame
data = pd.read_csv('titanic.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
data = data.dropna()

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
data.duplicated().sum()
# Out:
# 0

# %%
sns.countplot(x="Sex", data=data)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
plt.figure(figsize =(15,5))
sns.countplot(x="Embarked", hue= "Sex", data=data)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
#A) Count plot:

sns.countplot(data=df, x='Survived')
plt.show()

# %%
#B) Bar plot


sns.barplot(data=df, x='Pclass', y='Fare')
plt.show()

# %%
#C) Box plot:


sns.boxplot(data=df, x='Pclass', y='Age')
plt.show()

# %%
#D) Violin plot:


sns.violinplot(data=df, x='Pclass', y='Age')
plt.show()

# %%
#E) Strip plot:


sns.stripplot(data=df, x='Pclass', y='Fare')
plt.show()

# %%
#F) Swarm plot:


sns.swarmplot(data=df, x='Pclass', y='Fare')
plt.show()
# Out:
# C:\Users\Muhammad Farhan\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 21.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Muhammad Farhan\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 57.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Muhammad Farhan\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 78.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Muhammad Farhan\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 29.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Muhammad Farhan\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 64.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Muhammad Farhan\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 82.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#G) Factor plot:
sns.catplot(data=df, x='Pclass', y='Fare', kind='bar')
plt.show()

# %%
#H) Dist plot:

sns.displot(data=df, x='Age')
plt.show()

# %%
#I) Joint plot:


sns.jointplot(data=df, x='Age', y='Fare')
plt.show()

# %%
#K) Pair plot:


sns.pairplot(data=df, vars=['Age', 'Fare'])
plt.show()

# %%
#L) Rug plot:

sns.rugplot(data=df, x='Fare')
plt.show()

# %%
#M) Heatmap:

correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()
# Out:
# C:\Users\Muhammad Farhan\AppData\Local\Temp\ipykernel_7876\3982521547.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
#N) Scatter plot:


sns.scatterplot(data=df, x='Age', y='Fare', hue='Survived')
plt.show()

# %%
df['Title'] = df['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# %%
df['Title']
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886     Rev
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: Title, Length: 891, dtype: object

# %%
#Hypothesis Testing:
import scipy.stats as stats

# T-test or Mann-Whitney U test for age and survival
survived_age = df[df['Survived'] == 1]['Age'].dropna()
not_survived_age = df[df['Survived'] == 0]['Age'].dropna()

t_stat, p_value = stats.ttest_ind(survived_age, not_survived_age)
# or
u_stat, p_value = stats.mannwhitneyu(survived_age, not_survived_age)

print("Age and Survival:")
print("T-statistic:", t_stat)
print("P-value:", p_value)

# Chi-square test for Pclass and survival
cross_tab = pd.crosstab(df['Pclass'], df['Survived'])
chi2, p_value, dof, expected = stats.chi2_contingency(cross_tab)

print("\nPclass and Survival:")
print("Chi-square statistic:", chi2)
print("P-value:", p_value)
# Out:
# Age and Survival:
# T-statistic: -2.06668694625381
# P-value: 0.16049252477737763
#
# Pclass and Survival:
# Chi-square statistic: 102.88898875696056
# P-value: 4.549251711298793e-23

# %%
#Correlation Analysis:
import numpy as np

# Drop rows with missing values in both 'Age' and 'Fare'
age_fare_dropna = df[['Age', 'Fare']].dropna()

age = age_fare_dropna['Age']
fare = age_fare_dropna['Fare']

# Calculate Pearson's correlation coefficient
pearson_corr, pearson_p_value = stats.pearsonr(age, fare)

print("Correlation between Age and Fare:")
print("Pearson's correlation coefficient:", pearson_corr)
print("P-value:", pearson_p_value)

# Spearman's rank correlation coefficient for age and fare
spearman_corr, spearman_p_value = stats.spearmanr(age, fare)

print("\nCorrelation between Age and Fare:")
print("Spearman's rank correlation coefficient:", spearman_corr)
print("P-value:", spearman_p_value)
# Out:
# Correlation between Age and Fare:
# Pearson's correlation coefficient: 0.09606669176903906
# P-value: 0.010216277504441524
#
# Correlation between Age and Fare:
# Spearman's rank correlation coefficient: 0.1350512177342878
# P-value: 0.00029580903243060916

# %%
#Survival Analysis:
from lifelines import KaplanMeierFitter
from lifelines.statistics import logrank_test

# Drop rows with missing values in 'Age' and 'Survived' columns
df_survival = df[['Age', 'Survived']].dropna()

# Perform Kaplan-Meier estimation
kmf = KaplanMeierFitter()
kmf.fit(df_survival['Age'], event_observed=df_survival['Survived'])
kmf.plot_survival_function()
plt.xlabel('Age')
plt.ylabel('Survival Probability')
plt.title('Survival Probability by Age')
plt.show()

# %%
#Regression Analysis:
import statsmodels.api as sm

# Drop rows with missing or infinite values in 'Age' and 'Pclass' columns
X = df[['Age', 'Pclass']].replace([np.inf, -np.inf], np.nan).dropna()
y = df.loc[X.index, 'Survived']

X = sm.add_constant(X)  # Add a constant term
logit_model = sm.Logit(y, X)
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.579432
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Survived   No. Observations:                  714
# Model:                          Logit   Df Residuals:                      711
# Method:                           MLE   Df Model:                            2
# Date:                Sat, 15 Jul 2023   Pseudo R-squ.:                  0.1421
# Time:                        18:31:22   Log-Likelihood:                -413.71
# converged:                       True   LL-Null:                       -482.26
# Covariance Type:            nonrobust   LLR p-value:                 1.706e-30
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.5854      0.407      8.815      0.000       2.788       4.383
# Age           -0.0420      0.007     -6.246      0.000      -0.055      -0.029
# Pclass        -1.2439      0.119    -10.447      0.000      -1.477      -1.010
# ==============================================================================

# %%
#Descriptive Statistics:
# Summary statistics for age and fare
age_stats = df['Age'].describe()
fare_stats = df['Fare'].describe()

print("Age Summary Statistics:")
print(age_stats)

print("\nFare Summary Statistics:")
print(fare_stats)

# Mode for sex and embarkation port
sex_mode = df['Sex'].mode().values[0]
embarked_mode = df['Embarked'].mode().values[0]

print("\nSex Mode:", sex_mode)
print("Embarked Mode:", embarked_mode)
# Out:
# Age Summary Statistics:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64
#
# Fare Summary Statistics:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64
#
# Sex Mode: male
# Embarked Mode: S

# %%
#Group Comparisons:
# ANOVA or Kruskal-Wallis test for fare and passenger class
fare_class1 = df[df['Pclass'] == 1]['Fare'].dropna()
fare_class2 = df[df['Pclass'] == 2]['Fare'].dropna()
fare_class3 = df[df['Pclass'] == 3]['Fare'].dropna()

anova_stat, anova_p_value = stats.f_oneway(fare_class1, fare_class2, fare_class3)
# or
kruskal_stat, kruskal_p_value = stats.kruskal(fare_class1, fare_class2, fare_class3)

print("Fare and Passenger Class:")
print("ANOVA F-statistic:", anova_stat)
print("ANOVA P-value:", anova_p_value)
print("Kruskal-Wallis H-statistic:", kruskal_stat)
print("Kruskal-Wallis P-value:", kruskal_p_value)

# Chi-square test or Fisher's exact test for survival and gender
cross_tab_gender = pd.crosstab(df['Sex'], df['Survived'])
chi2_gender, p_value_gender, dof_gender, expected_gender = stats.chi2_contingency(cross_tab_gender)
# or
oddsratio_gender, p_value_gender = stats.fisher_exact(cross_tab_gender)

print("\nSurvival and Gender:")
print("Chi-square statistic:", chi2_gender)
print("P-value:", p_value_gender)
print("Odds ratio:", oddsratio_gender)
# Out:
# Fare and Passenger Class:
# ANOVA F-statistic: 242.34415651744814
# ANOVA P-value: 1.0313763209141171e-84
# Kruskal-Wallis H-statistic: 438.0437034212556
# Kruskal-Wallis P-value: 7.586096900646798e-96
#
# Survival and Gender:
# Chi-square statistic: 260.71702016732104
# P-value: 6.463921564583144e-60
# Odds ratio: 0.08096731594585672

# %%
# Feature Importance:


from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer

# Select the features and target variable
X = df[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare']]
y = df['Survived']

# Create an imputer to handle missing values
imputer = SimpleImputer(strategy='mean')

# Perform imputation on the numerical features
numerical_features = ['Age', 'Fare']
X[numerical_features] = imputer.fit_transform(X[numerical_features])

# Perform one-hot encoding on categorical variables
X_encoded = pd.get_dummies(X, columns=['Pclass', 'Sex'])

# Create an instance of the RandomForestClassifier
rf = RandomForestClassifier()

# Fit the model with the preprocessed data
rf.fit(X_encoded, y)

# Get feature importances
feature_importances = rf.feature_importances_

feature_importances
# Out:
# C:\Users\Muhammad Farhan\AppData\Local\Temp\ipykernel_7876\3482485436.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[numerical_features] = imputer.fit_transform(X[numerical_features])
# array([0.27062079, 0.04346068, 0.03119015, 0.27873982, 0.0283167 ,
#        0.01431286, 0.05464044, 0.16576423, 0.11295432])

# %%
X_encoded
# Out:
#           Age  SibSp  Parch      Fare  Pclass_1  Pclass_2  Pclass_3  \
# 0   -0.592481      1      0 -0.502445         0         0         1
# 1    0.638789      1      0  0.786845         1         0         0
# 2   -0.284663      0      0 -0.488854         0         0         1
# 3    0.407926      1      0  0.420730         1         0         0
# 4    0.407926      0      0 -0.486337         0         0         1
# ..        ...    ...    ...       ...       ...       ...       ...
# 886 -0.207709      0      0 -0.386671         0         1         0
# 887 -0.823344      0      0 -0.044381         1         0         0
# 888  0.000000      1      2 -0.176263         0         0         1
# 889 -0.284663      0      0 -0.044381         1         0         0
# 890  0.177063      0      0 -0.492378         0         0         1
#
#      Sex_female  Sex_male
# 0             0         1
# 1             1         0
# 2             1         0
# 3             1         0
# 4             0         1
# ..          ...       ...
# 886           0         1
# 887           1         0
# 888           1         0
# 889           0         1
# 890           0         1
#
# [891 rows x 9 columns]

# %%
# Cross-Validation and Model Evaluation:
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# Select the features and target variable
X = df[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare']]
y = df['Survived']

# Create an imputer to handle missing values
imputer = SimpleImputer(strategy='mean')

# Perform imputation on the numerical features
numerical_features = ['Age', 'Fare']
X[numerical_features] = imputer.fit_transform(X[numerical_features])

# Scale the numerical features
scaler = StandardScaler()
X[numerical_features] = scaler.fit_transform(X[numerical_features])

# Perform one-hot encoding on categorical variables
X_encoded = pd.get_dummies(X, columns=['Pclass', 'Sex'])

# Create an instance of the LogisticRegression model
lr = LogisticRegression(max_iter=1000)

# Fit the model with the preprocessed data
lr.fit(X_encoded, y)

# Print the coefficients
print(lr.coef_)
# Out:
# [[-0.49325406 -0.34104052 -0.10958963  0.16533649  0.99988887  0.04645605
#   -1.0463882   1.34619769 -1.34624097]]
# C:\Users\Muhammad Farhan\AppData\Local\Temp\ipykernel_7876\3883781209.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[numerical_features] = imputer.fit_transform(X[numerical_features])
# C:\Users\Muhammad Farhan\AppData\Local\Temp\ipykernel_7876\3883781209.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[numerical_features] = scaler.fit_transform(X[numerical_features])

# %%
# Model Comparison:
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier


models = [
    ('Logistic Regression', LogisticRegression()),
    ('Random Forest', RandomForestClassifier())
]

for name, model in models:
    scores = cross_val_score(model, X_encoded, y, cv=20)
    mean_accuracy = scores.mean()
    print(f"{name}: Mean Accuracy = {mean_accuracy}")
# Out:
# Logistic Regression: Mean Accuracy = 0.7979797979797981
# Random Forest: Mean Accuracy = 0.8183333333333334

# %%
# Feature Engineering:
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
df['FamilySize']
# Out:
# 0      2
# 1      2
# 2      1
# 3      2
# 4      1
#       ..
# 886    1
# 887    1
# 888    4
# 889    1
# 890    1
# Name: FamilySize, Length: 891, dtype: int64

# %%
# Dimensionality Reduction:
from sklearn.decomposition import PCA



pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_encoded)
X_pca
# Out:
# array([[ 0.21692179, -0.97773684],
#        [ 0.32986341,  1.3283054 ],
#        [-0.44088024, -0.59695781],
#        ...,
#        [ 1.12937221, -0.15176271],
#        [-0.53937273,  0.12930622],
#        [-0.82894725, -0.48904138]])

# %%
# Model Hyperparameter Tuning:
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

# Select the features and target variable
X = df[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare']]
y = df['Survived']

# Create an imputer to handle missing values
imputer = SimpleImputer(strategy='mean')

# Perform imputation on the numerical features
numerical_features = ['Age', 'Fare']
X[numerical_features] = imputer.fit_transform(X[numerical_features])

# Scale the numerical features
scaler = StandardScaler()
X[numerical_features] = scaler.fit_transform(X[numerical_features])

# Perform one-hot encoding on categorical variables
X_encoded = pd.get_dummies(X, columns=['Pclass', 'Sex'])

# Create an instance of the LogisticRegression model
lr = LogisticRegression(max_iter=1000, penalty='l1', solver='liblinear')

# Define the hyperparameter grid for grid search
param_grid = {'C': [0.1, 1, 10]}

# Perform grid search cross-validation
grid_search = GridSearchCV(lr, param_grid, cv=5)
grid_search.fit(X_encoded, y)

# Print the best parameter and score
print("Best Parameter:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)
# Out:
# Best Parameter: {'C': 1}
# Best Score: 0.7901261691042621
# C:\Users\Muhammad Farhan\AppData\Local\Temp\ipykernel_7876\1448006180.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[numerical_features] = imputer.fit_transform(X[numerical_features])
# C:\Users\Muhammad Farhan\AppData\Local\Temp\ipykernel_7876\1448006180.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[numerical_features] = scaler.fit_transform(X[numerical_features])

# %%
# Ensemble Methods:
import matplotlib.pyplot as plt
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_classification
from sklearn.tree import plot_tree

# Generate a synthetic dataset
X, y = make_classification(n_samples=1000, n_features=10, random_state=42)

# Train the BaggingClassifier with DecisionTreeClassifier as the base model
base_model = DecisionTreeClassifier()
bagging_model = BaggingClassifier(base_model)
bagging_model.fit(X, y)

# Fit the base model
base_model.fit(X, y)

# Extract a decision tree from the base model
tree = base_model

# Plot the decision tree
plt.figure(figsize=(12, 6))
plt.title("Decision Tree Visualization")
_ = plot_tree(tree, filled=True, feature_names=['feature_{}'.format(i) for i in range(10)])

# Get the model summary
n_estimators = bagging_model.n_estimators

print("Number of Base Estimators:", n_estimators)

# Get the individual feature importances of the base estimators
feature_importances = [estimator.feature_importances_ for estimator in bagging_model.estimators_]

# Calculate the average feature importances across base estimators
average_feature_importances = sum(feature_importances) / n_estimators

print("Average Feature Importances:")
for i, importance in enumerate(average_feature_importances):
    print("Feature {}: Importance = {:.4f}".format(i, importance))
# Out:
# Number of Base Estimators: 10
# Average Feature Importances:
# Feature 0: Importance = 0.0211
# Feature 1: Importance = 0.0219
# Feature 2: Importance = 0.0425
# Feature 3: Importance = 0.0226
# Feature 4: Importance = 0.0366
# Feature 5: Importance = 0.0165
# Feature 6: Importance = 0.6351
# Feature 7: Importance = 0.0259
# Feature 8: Importance = 0.1536
# Feature 9: Importance = 0.0242

# %%
# Interpretation and Visualization:
import pandas as pd
import xgboost as xgb
import shap



# Drop irrelevant columns
df = data.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1)

# Handle missing values
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# Encode categorical variables
df_encoded = pd.get_dummies(df, drop_first=True)

# Separate features and target variable
X = df_encoded.drop('Survived', axis=1)
y = df_encoded['Survived']

# Train the XGBoost model
try:
    xgb_model = xgb.XGBClassifier()
    xgb_model.fit(X, y)
except Exception as e:
    print(f"Error occurred while training XGBoost model: {str(e)}")

# Generate SHAP values for feature importance
try:
    explainer = shap.Explainer(xgb_model)
    shap_values = explainer.shap_values(X)
except Exception as e:
    print(f"Error occurred while generating SHAP values: {str(e)}")

# Plot feature importance
try:
    shap.summary_plot(shap_values, X, plot_type='bar')
except Exception as e:
    print(f"Error occurred while plotting SHAP summary: {str(e)}")

# %%
#

# %%
#

# %%
#

# %%
#

# %%
#
